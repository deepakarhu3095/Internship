# %%
#Importing required libraries
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, ElementNotInteractableException

# %%
import time
# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia:

# %%
# Activating the chrome browser
driver = webdriver.Chrome(r"C:\Users\InderJeet\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/1165227785.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\InderJeet\chromedriver_win32\chromedriver.exe")

# %%
#Getting the website to driver
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

#When we run this line, automatically the webpage will be opened

# %%
#Creating the empty lists to store the scraped data
Rank=[]
Name=[]
Artist=[]
Views=[]
Upload_Date=[]

#As we need only the first 30 details, we will iterate only for first 30 data
#Scrapping the details of the Rank of the video
rank=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[1]")
for i in rank[:30]:
    Rank.append(i.text)
    
#Scrapping the details of the video name
video=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[2]")
for i in video[:30]:
    Name.append(i.text)
    
#Scrapping the details of the Artist name
artist=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[3]")
for i in artist[:30]:
    Artist.append(i.text)
    
#Scrapping the details of the views information
views=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[4]")
for i in views[:30]:
    Views.append(i.text)
    
#Scrapping the details of the upload date
date=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[5]")
for i in date[:30]:
    Upload_Date.append(i.text)
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/3263091120.py:10: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   rank=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[1]")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/3263091120.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   video=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[2]")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/3263091120.py:20: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   artist=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[3]")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/3263091120.py:25: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   views=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[4]")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/3263091120.py:30: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   date=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[5]")

# %%
#Creating a dataframe for storing the scraped data
Yt_data=pd.DataFrame({})
Yt_data['Rank']=Rank
Yt_data['Video Name']=Name
Yt_data['Artist']=Artist
Yt_data['Views(Billions)']=Views
Yt_data['Upload Date']=Upload_Date
Yt_data
# Out:
#    Rank                                       Video Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.  "Learning Colors – Colorful Eggs on a Farm"[22]
# 8    9.                                "Uptown Funk"[23]
# 9   10.   "Masha and the Bear – Recipe for Disaster"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# 15  16.                             "Counting Stars"[34]
# 16  17.                                      "Sorry"[35]
# 17  18.                          "Thinking Out Loud"[36]
# 18  19.                                     "Axel F"[37]
# 19  20.                             "Girls Like You"[38]
# 20  21.                                      "Faded"[39]
# 21  22.                                 "Dark Horse"[40]
# 22  23.                                 "Let Her Go"[41]
# 23  24.                        "Baa Baa Black Sheep"[42]
# 24  25.                                   "Bailando"[43]
# 25  26.                                    "Lean On"[44]
# 26  27.                               "Shake It Off"[45]
# 27  28.                                    "Perfect"[46]
# 28  29.           "Waka Waka (This Time for Africa)"[47]
# 29  30.                                   "Mi Gente"[48]
#
#                                          Artist Views(Billions)  \
# 0   Pinkfong Baby Shark - Kids' Songs & Stories           10.53
# 1                                    Luis Fonsi            7.82
# 2                                   LooLoo Kids            6.31
# 3                                    Ed Sheeran            5.69
# 4                                   Wiz Khalifa            5.48
# 5                    Cocomelon – Nursery Rhymes            5.27
# 6                                     ChuChu TV            4.58
# 7                                   Miroshka TV            4.56
# 8                                   Mark Ronson            4.54
# 9                                    Get Movies            4.49
# 10                                          Psy            4.40
# 11                   Cocomelon – Nursery Rhymes            3.96
# 12                                    El Chombo            3.92
# 13                                     Maroon 5            3.68
# 14                                   Katy Perry            3.56
# 15                                  OneRepublic            3.56
# 16                                Justin Bieber            3.54
# 17                                   Ed Sheeran            3.44
# 18                                   Crazy Frog            3.32
# 19                                     Maroon 5            3.28
# 20                                  Alan Walker            3.27
# 21                                   Katy Perry            3.26
# 22                                    Passenger            3.21
# 23                   Cocomelon – Nursery Rhymes            3.21
# 24                             Enrique Iglesias            3.19
# 25                                  Major Lazer            3.19
# 26                                 Taylor Swift            3.16
# 27                                   Ed Sheeran            3.14
# 28                                      Shakira            3.12
# 29                                     J Balvin            3.07
#
#           Upload Date
# 0       June 17, 2016
# 1    January 12, 2017
# 2     October 8, 2016
# 3    January 30, 2017
# 4       April 6, 2015
# 5         May 2, 2018
# 6       March 6, 2014
# 7   February 27, 2018
# 8   November 19, 2014
# 9    January 31, 2012
# 10      July 15, 2012
# 11       May 24, 2018
# 12      April 5, 2018
# 13   January 14, 2015
# 14  September 5, 2013
# 15       May 31, 2013
# 16   October 22, 2015
# 17    October 7, 2014
# 18      June 16, 2009
# 19       May 31, 2018
# 20   December 3, 2015
# 21  February 20, 2014
# 22      July 25, 2012
# 23      June 25, 2018
# 24     April 11, 2014
# 25     March 22, 2015
# 26    August 18, 2014
# 27   November 9, 2017
# 28       June 4, 2010
# 29      June 29, 2017

# %%
#Removing the stray numbers from videoname
new=Yt_data["Video Name"].str.split("[", n = 1, expand = True) 
new
# Out:
#                                               0    1
# 0                            "Baby Shark Dance"   3]
# 1                                   "Despacito"   6]
# 2                        "Johny Johny Yes Papa"  12]
# 3                                "Shape of You"  13]
# 4                               "See You Again"  15]
# 5                                   "Bath Song"  20]
# 6                 "Phonics Song with Two Words"  21]
# 7   "Learning Colors – Colorful Eggs on a Farm"  22]
# 8                                 "Uptown Funk"  23]
# 9    "Masha and the Bear – Recipe for Disaster"  24]
# 10                              "Gangnam Style"  25]
# 11                          "Wheels on the Bus"  30]
# 12                             "Dame Tu Cosita"  31]
# 13                                      "Sugar"  32]
# 14                                       "Roar"  33]
# 15                             "Counting Stars"  34]
# 16                                      "Sorry"  35]
# 17                          "Thinking Out Loud"  36]
# 18                                     "Axel F"  37]
# 19                             "Girls Like You"  38]
# 20                                      "Faded"  39]
# 21                                 "Dark Horse"  40]
# 22                                 "Let Her Go"  41]
# 23                        "Baa Baa Black Sheep"  42]
# 24                                   "Bailando"  43]
# 25                                    "Lean On"  44]
# 26                               "Shake It Off"  45]
# 27                                    "Perfect"  46]
# 28           "Waka Waka (This Time for Africa)"  47]
# 29                                   "Mi Gente"  48]

# %%
#Dropping the column with stray numbers
Yt_data.drop(columns=['Video Name'],axis=1,inplace=True)

#Inserting the name column
Yt_data.insert(1,"Video Name",new[0])

#Checking the data after removing the stray numbers
Yt_data
# Out:
#    Rank                                   Video Name  \
# 0    1.                           "Baby Shark Dance"
# 1    2.                                  "Despacito"
# 2    3.                       "Johny Johny Yes Papa"
# 3    4.                               "Shape of You"
# 4    5.                              "See You Again"
# 5    6.                                  "Bath Song"
# 6    7.                "Phonics Song with Two Words"
# 7    8.  "Learning Colors – Colorful Eggs on a Farm"
# 8    9.                                "Uptown Funk"
# 9   10.   "Masha and the Bear – Recipe for Disaster"
# 10  11.                              "Gangnam Style"
# 11  12.                          "Wheels on the Bus"
# 12  13.                             "Dame Tu Cosita"
# 13  14.                                      "Sugar"
# 14  15.                                       "Roar"
# 15  16.                             "Counting Stars"
# 16  17.                                      "Sorry"
# 17  18.                          "Thinking Out Loud"
# 18  19.                                     "Axel F"
# 19  20.                             "Girls Like You"
# 20  21.                                      "Faded"
# 21  22.                                 "Dark Horse"
# 22  23.                                 "Let Her Go"
# 23  24.                        "Baa Baa Black Sheep"
# 24  25.                                   "Bailando"
# 25  26.                                    "Lean On"
# 26  27.                               "Shake It Off"
# 27  28.                                    "Perfect"
# 28  29.           "Waka Waka (This Time for Africa)"
# 29  30.                                   "Mi Gente"
#
#                                          Artist Views(Billions)  \
# 0   Pinkfong Baby Shark - Kids' Songs & Stories           10.53
# 1                                    Luis Fonsi            7.82
# 2                                   LooLoo Kids            6.31
# 3                                    Ed Sheeran            5.69
# 4                                   Wiz Khalifa            5.48
# 5                    Cocomelon – Nursery Rhymes            5.27
# 6                                     ChuChu TV            4.58
# 7                                   Miroshka TV            4.56
# 8                                   Mark Ronson            4.54
# 9                                    Get Movies            4.49
# 10                                          Psy            4.40
# 11                   Cocomelon – Nursery Rhymes            3.96
# 12                                    El Chombo            3.92
# 13                                     Maroon 5            3.68
# 14                                   Katy Perry            3.56
# 15                                  OneRepublic            3.56
# 16                                Justin Bieber            3.54
# 17                                   Ed Sheeran            3.44
# 18                                   Crazy Frog            3.32
# 19                                     Maroon 5            3.28
# 20                                  Alan Walker            3.27
# 21                                   Katy Perry            3.26
# 22                                    Passenger            3.21
# 23                   Cocomelon – Nursery Rhymes            3.21
# 24                             Enrique Iglesias            3.19
# 25                                  Major Lazer            3.19
# 26                                 Taylor Swift            3.16
# 27                                   Ed Sheeran            3.14
# 28                                      Shakira            3.12
# 29                                     J Balvin            3.07
#
#           Upload Date
# 0       June 17, 2016
# 1    January 12, 2017
# 2     October 8, 2016
# 3    January 30, 2017
# 4       April 6, 2015
# 5         May 2, 2018
# 6       March 6, 2014
# 7   February 27, 2018
# 8   November 19, 2014
# 9    January 31, 2012
# 10      July 15, 2012
# 11       May 24, 2018
# 12      April 5, 2018
# 13   January 14, 2015
# 14  September 5, 2013
# 15       May 31, 2013
# 16   October 22, 2015
# 17    October 7, 2014
# 18      June 16, 2009
# 19       May 31, 2018
# 20   December 3, 2015
# 21  February 20, 2014
# 22      July 25, 2012
# 23      June 25, 2018
# 24     April 11, 2014
# 25     March 22, 2015
# 26    August 18, 2014
# 27   November 9, 2017
# 28       June 4, 2010
# 29      June 29, 2017

# %%
#Closing the driver
driver.close()

# %% [markdown]
# 2.Scrape the details team India’s international fixtures from bcci.tv.
#
# Url = https://www.bcci.tv/
#
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# Activating the chrome browser
driver = webdriver.Chrome(r"C:\Users\InderJeet\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/1165227785.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\InderJeet\chromedriver_win32\chromedriver.exe")

# %%
#Getting the website to driver
driver.get('https://www.bcci.tv/')

#When we run this line, automatically the webpage will be opened

# %%
#Clicking international fixture section
international=driver.find_element_by_xpath("//ul[@class='navigation__list showMoreEnabled']/li[1]/div[2]/div/ul/li[1]/a")
driver.get(international.get_attribute('href'))
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/2996082803.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   international=driver.find_element_by_xpath("//ul[@class='navigation__list showMoreEnabled']/li[1]/div[2]/div/ul/li[1]/a")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/2996082803.py in <module>
#       1 #Clicking international fixture section
# ----> 2 international=driver.find_element_by_xpath("//ul[@class='navigation__list showMoreEnabled']/li[1]/div[2]/div/ul/li[1]/a")
#       3 driver.get(international.get_attribute('href'))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     519             stacklevel=2,
#     520         )
# --> 521         return self.find_element(by=By.XPATH, value=xpath)
#     522
#     523     def find_elements_by_xpath(self, xpath) -> List[WebElement]:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1246             value = '[name="%s"]' % value
#    1247
# -> 1248         return self.execute(Command.FIND_ELEMENT, {
#    1249             'using': by,
#    1250             'value': value})['value']
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//ul[@class='navigation__list showMoreEnabled']/li[1]/div[2]/div/ul/li[1]/a"}
#   (Session info: chrome=100.0.4896.127)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x010E9943+2595139]
# 	Ordinal0 [0x0107C9F1+2148849]
# 	Ordinal0 [0x00F74528+1066280]
# 	Ordinal0 [0x00FA0FD4+1249236]
# 	Ordinal0 [0x00FA11CB+1249739]
# 	Ordinal0 [0x00FCD812+1431570]
# 	Ordinal0 [0x00FBBA34+1358388]
# 	Ordinal0 [0x00FCBAF2+1424114]
# 	Ordinal0 [0x00FBB806+1357830]
# 	Ordinal0 [0x00F96086+1204358]
# 	Ordinal0 [0x00F96F96+1208214]
# 	GetHandleVerifier [0x0128B232+1658114]
# 	GetHandleVerifier [0x0134312C+2411516]
# 	GetHandleVerifier [0x0117F261+560433]
# 	GetHandleVerifier [0x0117E366+556598]
# 	Ordinal0 [0x0108286B+2173035]
# 	Ordinal0 [0x010875F8+2192888]
# 	Ordinal0 [0x010876E5+2193125]
# 	Ordinal0 [0x010911FC+2232828]
# 	BaseThreadInitThunk [0x75E4919F+14]
# 	RtlInitializeExceptionChain [0x7776AD1F+143]
# 	RtlInitializeExceptionChain [0x7776ACEA+90]

# %%
#Creating empty lists for storing the scrapped data
Match=[]
Series=[]
Place=[]
Date=[]
Time=[]

#Scrapping the data having the match name
name=driver.find_elements_by_xpath("//strong[@class='fixture__name fixture__name--with-margin']")
for i in name:
    Match.append(i.text)

#Scrapping the data having the series name
series=driver.find_elements_by_xpath("//div[@class='fixture__format-strip']/span[2]")
for i in series:
    Series.append(i.text)
    
#Scrapping the data having the place of match
place=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/span")
for i in place:
    Place.append(i.text)
    
#Scrapping the data having the match date
date=driver.find_elements_by_xpath("//div[@class='fixture__datetime desktop-only']/div/span")  #Only date
month=driver.find_elements_by_xpath("//div[@class='fixture__datetime desktop-only']/div/div/span[1]")  #Month
for i in range(len(date)):
    Date.append(date[i].text + month[i].text)  #Appending date and month texts together
    
#Scrapping the data having match time
time=driver.find_elements_by_xpath("//div[@class='fixture__full-date']/div/span[2]")
for i in time:
    Time.append(i.text)
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/171702334.py:9: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   name=driver.find_elements_by_xpath("//strong[@class='fixture__name fixture__name--with-margin']")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/171702334.py:14: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   series=driver.find_elements_by_xpath("//div[@class='fixture__format-strip']/span[2]")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/171702334.py:19: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   place=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/span")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/171702334.py:24: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   date=driver.find_elements_by_xpath("//div[@class='fixture__datetime desktop-only']/div/span")  #Only date
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/171702334.py:25: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   month=driver.find_elements_by_xpath("//div[@class='fixture__datetime desktop-only']/div/div/span[1]")  #Month
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/171702334.py:30: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   time=driver.find_elements_by_xpath("//div[@class='fixture__full-date']/div/span[2]")

# %%
#Creating a Dataframe for the scrapped data
fixtures=pd.DataFrame({})
fixtures['Match name']=Match
fixtures['Series']=Series
fixtures['Place']=Place
fixtures['Date']=Date
fixtures['Time']=Time
fixtures
# Out:
# Empty DataFrame
# Columns: [Match name, Series, Place, Date, Time]
# Index: []

# %% [markdown]
# 3.Scrape the details of selenium exception from guru99.com.
#
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
#Getting the website to driver
driver.get('https://www.guru99.com/')

#When we run this line, automatically the webpage will be opened

# %%
#Clicking on the selenium tutorial page 
driver.find_element_by_xpath("//div[@class='srch']/span[8]/a").click()

#Clicking on the selenium exception tutorial page
driver.find_element_by_xpath("//table[@class='table']/tbody/tr[34]/td/a").click()
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/792321341.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//div[@class='srch']/span[8]/a").click()
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/792321341.py:5: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//table[@class='table']/tbody/tr[34]/td/a").click()

# %%
#Creating the empty lists to store the scraped data
Name=[]
Description=[]

#Scrapping the data having exception names
name=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")
for i in name:
    Name.append(i.text)
    
#Scrapping the data having the description details  
desc=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")
for i in desc:
    Description.append(i.text)
    
#Checking the length of the data scrapped
print(len(Name),len(Description))
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/4199939071.py:6: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   name=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/4199939071.py:11: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   desc=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")
# 41 41

# %%
#Creating a dataframe for the scrapped data
guru99=pd.DataFrame({})
guru99['Exception Name']=Name[1:]
guru99['Description']=Description[1:]
guru99
# Out:
#                          Exception Name  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# 22       InvalidSwitchToTargetException
# 23                  JavascriptException
# 24                        JsonException
# 25             NoSuchAttributeException
# 26       MoveTargetOutOfBoundsException
# 27               NoSuchContextException
# 28                NoSuchCookieException
# 29                    NotFoundException
# 30          RemoteDriverServerException
# 31                  ScreenshotException
# 32           SessionNotCreatedException
# 33           UnableToSetCookieException
# 34           UnexpectedTagNameException
# 35              UnhandledAlertException
# 36      UnexpectedAlertPresentException
# 37               UnknownMethodException
# 38          UnreachableBrowserException
# 39          UnsupportedCommandException
#
#                                           Description
# 0   This Selenium exception occurs when an element...
# 1   This Exception occurs if an element could not ...
# 2   This Exception occurs if the frame target to b...
# 3   This Exception occurs when you switch to no pr...
# 4   This Exception occurs if the window target to ...
# 5   This Selenium exception occurs happens when th...
# 6   The WebDriver is acting after you quit the bro...
# 7   Thrown when there is not enough time for a com...
# 8   This Exception takes place when the WebDriver ...
# 9   This type of Exception takes place when there ...
# 10  The command may not be completed as the elemen...
# 11  This Selenium exception is thrown when any ele...
# 12  This happens while interacting with the Firefo...
# 13  Exception is used as a placeholder in case if ...
# 14  This expectation will occur when IME engine ac...
# 15    It takes place when IME support is unavailable.
# 16  Navigation made the user agent to hit a certif...
# 17  It occurs when an argument does not belong to ...
# 18  This happens when you try to add a cookie unde...
# 19  This type of Exception matches an interacting ...
# 20  It occurs when command can’t be finished when ...
# 21  This Exception took place when the given sessi...
# 22  This occurs when the frame or window target to...
# 23  This issue occurs while executing JavaScript g...
# 24  It occurs when you afford to get the session w...
# 25  This kind of Exception occurs when the attribu...
# 26  It takes place if the target provided to the A...
# 27           ContextAware does mobile device testing.
# 28  This Exception occurs when no cookie matching ...
# 29  This Exception is a subclass of WebDriverExcep...
# 30  This Selenium exception is thrown when the ser...
# 31            It is not possible to capture a screen.
# 32  It happens when a new session could not be suc...
# 33  This occurs if a driver is unable to set a coo...
# 34  Happens if a support class did not get a web e...
# 35  This expectation occurs when there is an alert...
# 36  It occurs when there is the appearance of an u...
# 37  This Exception happens when the requested comm...
# 38  This Exception occurs only when the browser is...
# 39  This occurs when remote WebDriver does n’t sen...

# %% [markdown]
# 4.Scrape the details of State-wise GDP of India from statisticstime.com.
#
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP(19-20)
#
# D) GSDP(18-19)
#
# E) Share(18-19)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
# Activating the chrome browser
driver = webdriver.Chrome(r"C:\Users\InderJeet\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/1165227785.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\InderJeet\chromedriver_win32\chromedriver.exe")

# %%
#Getting the website to driver
driver.get('http://statisticstimes.com/')

#When we run this line, automatically the webpage will be opened

# %%
#Clicking the economy tab and then India option
economy=driver.find_element_by_xpath("//div[@class='navbar']/div[2]/div/a[3]")
try:
    economy.click()
except ElementNotInteractableException:
    driver.get(economy.get_attribute('href'))
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/3386114098.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   economy=driver.find_element_by_xpath("//div[@class='navbar']/div[2]/div/a[3]")

# %%
#Clicking on GDP of Indian states option
gdp=driver.find_element_by_xpath("//div[@style='float:left;background-color:seashell;width:400px;height:800px;']/ul/li[1]")
try:
    gdp.click()
except ElementNotInteractableException:
    driver.get(gdp.get_attribute('href'))
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/3825918272.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   gdp=driver.find_element_by_xpath("//div[@style='float:left;background-color:seashell;width:400px;height:800px;']/ul/li[1]")

# %%
#Creating empty lists for storing the scrapped data
Rank=[]
State=[]
GSDP19_20=[]
GSDP18_19=[]
Share18_19=[]
GDP=[]

#Scrapping the data having rank of the states
rank=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[1]")
for i in rank:
    Rank.append(i.text)
    
#Scrapping the data having State name
state=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[2]")
for i in state:
    State.append(i.text)
    
#Scrapping the data having GSDP 19-20 data
for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[3]"):
    GSDP19_20.append(i.text)
    
#Scrapping the data having GSDP 18-19 data
for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[4]"):
    GSDP18_19.append(i.text)
    
#Scrapping the data having Share 18-19 data
for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[5]"):
    Share18_19.append(i.text)
    
#Scrapping the data having GDP billions data
for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[6]"):
    GDP.append(i.text)
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/2004468626.py:10: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   rank=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[1]")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/2004468626.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   state=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[2]")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/2004468626.py:20: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[3]"):
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/2004468626.py:24: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[4]"):
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/2004468626.py:28: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[5]"):
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/2004468626.py:32: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[6]"):

# %%
#Creating a dataframe for the scrapped data
GDP_data=pd.DataFrame({'Rank':Rank,'State':State,'GSDP(19-20)':GSDP19_20,'GSDP(18-19)':GSDP18_19,'Share(18-19)':Share18_19,
                      'GDP($ billion)':GDP})
GDP_data
# Out:
#    Rank                      State GSDP(19-20) GSDP(18-19) Share(18-19)  \
# 0     1                Maharashtra           -   2,632,792       13.94%
# 1     2                 Tamil Nadu   1,845,853   1,630,208        8.63%
# 2     3              Uttar Pradesh   1,687,818   1,584,764        8.39%
# 3     4                    Gujarat           -   1,502,899        7.96%
# 4     5                  Karnataka   1,631,977   1,493,127        7.91%
# ..  ...                        ...         ...         ...          ...
# 61   29                     Sikkim      28,391      25,141        0.15%
# 62   30                   Nagaland           -      24,534        0.15%
# 63   31          Arunachal Pradesh           -      22,488        0.13%
# 64   32                    Mizoram      24,424      20,947        0.13%
# 65   33  Andaman & Nicobar Islands           -           -            -
#
#    GDP($ billion)
# 0         399.921
# 1         247.629
# 2         240.726
# 3         228.290
# 4         226.806
# ..            ...
# 61         17,060
# 62              -
# 63              -
# 64         17,797
# 65              -
#
# [66 rows x 6 columns]

# %% [markdown]
# 5.Scrape the details of trending repositories on Github.com.
#
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
#Getting the website to driver
driver.get('https://github.com/')

#When we run this line, automatically the webpage will be opened

# %%
Repository_Name =[]
Language=[]
Muted_Link=[]

# %%
explore = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details')       # Locating page foe top videos by xpath
explore.click()
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/1552727046.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   explore = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details')       # Locating page foe top videos by xpath
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_5924/1552727046.py in <module>
#       1 explore = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details')       # Locating page foe top videos by xpath
# ----> 2 explore.click()
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      79     def click(self) -> None:
#      80         """Clicks the element."""
# ---> 81         self._execute(Command.CLICK_ELEMENT)
#      82
#      83     def submit(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     708             params = {}
#     709         params['id'] = self._id
# --> 710         return self._parent.execute(command, params)
#     711
#     712     def find_element(self, by=By.ID, value=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=100.0.4896.127)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x010E9943+2595139]
# 	Ordinal0 [0x0107C9F1+2148849]
# 	Ordinal0 [0x00F743F0+1065968]
# 	Ordinal0 [0x00FA1F17+1253143]
# 	Ordinal0 [0x00F97AB3+1211059]
# 	Ordinal0 [0x00FBB9EC+1358316]
# 	Ordinal0 [0x00F97474+1209460]
# 	Ordinal0 [0x00FBBC04+1358852]
# 	Ordinal0 [0x00FCBAF2+1424114]
# 	Ordinal0 [0x00FBB806+1357830]
# 	Ordinal0 [0x00F96086+1204358]
# 	Ordinal0 [0x00F96F96+1208214]
# 	GetHandleVerifier [0x0128B232+1658114]
# 	GetHandleVerifier [0x0134312C+2411516]
# 	GetHandleVerifier [0x0117F261+560433]
# 	GetHandleVerifier [0x0117E366+556598]
# 	Ordinal0 [0x0108286B+2173035]
# 	Ordinal0 [0x010875F8+2192888]
# 	Ordinal0 [0x010876E5+2193125]
# 	Ordinal0 [0x010911FC+2232828]
# 	BaseThreadInitThunk [0x75E4919F+14]
# 	RtlInitializeExceptionChain [0x7776AD1F+143]
# 	RtlInitializeExceptionChain [0x7776ACEA+90]

# %% [markdown]
# 6.Scrape the details of top 100 songs on billiboard.com.
#
# Url = https://www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# Activating the chrome browser
driver = webdriver.Chrome(r"C:\Users\InderJeet\chromedriver_win32\chromedriver.exe")
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_4892/1165227785.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\InderJeet\chromedriver_win32\chromedriver.exe")

# %%
#Getting the website to driver
driver.get('https://www.billboard.com/')

#When we run this line, automatically the webpage will be opened

# %%
#Clicking charts and then hot100 option
hot_100=driver.find_element_by_xpath("//nav[@class='header__subnav bg--light']/ul/li[3]/a")
try:
    hot_100.click()
except ElementNotInteractableException:
    driver.get(hot_100.get_attribute('href'))
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_4892/1413842866.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   hot_100=driver.find_element_by_xpath("//nav[@class='header__subnav bg--light']/ul/li[3]/a")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_4892/1413842866.py in <module>
#       1 #Clicking charts and then hot100 option
# ----> 2 hot_100=driver.find_element_by_xpath("//nav[@class='header__subnav bg--light']/ul/li[3]/a")
#       3 try:
#       4     hot_100.click()
#       5 except ElementNotInteractableException:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     519             stacklevel=2,
#     520         )
# --> 521         return self.find_element(by=By.XPATH, value=xpath)
#     522
#     523     def find_elements_by_xpath(self, xpath) -> List[WebElement]:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1246             value = '[name="%s"]' % value
#    1247
# -> 1248         return self.execute(Command.FIND_ELEMENT, {
#    1249             'using': by,
#    1250             'value': value})['value']
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//nav[@class='header__subnav bg--light']/ul/li[3]/a"}
#   (Session info: chrome=100.0.4896.127)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01499943+2595139]
# 	Ordinal0 [0x0142C9F1+2148849]
# 	Ordinal0 [0x01324528+1066280]
# 	Ordinal0 [0x01350FD4+1249236]
# 	Ordinal0 [0x013511CB+1249739]
# 	Ordinal0 [0x0137D812+1431570]
# 	Ordinal0 [0x0136BA34+1358388]
# 	Ordinal0 [0x0137BAF2+1424114]
# 	Ordinal0 [0x0136B806+1357830]
# 	Ordinal0 [0x01346086+1204358]
# 	Ordinal0 [0x01346F96+1208214]
# 	GetHandleVerifier [0x0163B232+1658114]
# 	GetHandleVerifier [0x016F312C+2411516]
# 	GetHandleVerifier [0x0152F261+560433]
# 	GetHandleVerifier [0x0152E366+556598]
# 	Ordinal0 [0x0143286B+2173035]
# 	Ordinal0 [0x014375F8+2192888]
# 	Ordinal0 [0x014376E5+2193125]
# 	Ordinal0 [0x014411FC+2232828]
# 	BaseThreadInitThunk [0x75E4919F+14]
# 	RtlInitializeExceptionChain [0x7776AD1F+143]
# 	RtlInitializeExceptionChain [0x7776ACEA+90]

# %%
#Creating empty lists for storing the scrapped data
Song=[]
Artist=[]
Lastweek=[]
Peak=[]
Weeks_on_board=[]

#Scrapping the data having the song name
song=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
for i in song:
    Song.append(i.text)
    
#Scrapping the data having the artist name
artist=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
for i in artist:
    Artist.append(i.text)
    
#Scrapping the data having the last week rank
last_week=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
for i in last_week:
    if i.text is None:
        Lastweek.append('-')
    else:
        Lastweek.append(i.text)
        
#Scrapping the data having the peak rank
peak=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
for i in peak:
    if i.text is None:
        Peak.append('-')
    else:
        Peak.append(i.text)
        
#Scrapping the data having weeks on board data
weeks=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
for i in weeks:
    if i.text is None:
        Weeks_on_board.append('-')
    else:
        Weeks_on_board.append(i.text)
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_4892/543251654.py:9: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   song=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_4892/543251654.py:14: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   artist=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_4892/543251654.py:19: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   last_week=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_4892/543251654.py:27: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   peak=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_4892/543251654.py:35: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   weeks=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")

# %%
#Creating a dataframe for the scrapped data
billboard=pd.DataFrame({'Song':Song,'Artist':Artist,'Last week Rank':Lastweek,'Peak Rank':Peak,'Weeks on board':Weeks_on_board})
billboard
# Out:
# Empty DataFrame
# Columns: [Song, Artist, Last week Rank, Peak Rank, Weeks on board]
# Index: []

# %%
#Closing the driver
driver.close()

# %% [markdown]
# 7.Scrape the details of Data science recruiters from naukri.com.
#
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException

#Importing requests
import requests

# importing regex
import re

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

# Opening the naukri.com
url = "https://www.naukri.com/"
driver.get(url)
time.sleep(2)

#clicking on recruiters link
recruiters=driver.find_element_by_xpath("//a[@title='Search Recruiters']")
driver.get(recruiters.get_attribute('href'))
time.sleep(1)

#accesing search bar
search=driver.find_element_by_xpath("//input[@class='sugInp']")
search.send_keys("Data Science")
time.sleep(1)

#clicking on search button
button=driver.find_element_by_xpath("//button[@id='qsbFormBtn']")
button.click()
time.sleep(1)

#scrapping names
name=[]
try:
    names=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[1]")
    for i in names:
        name.append(i.text)
except NoSuchElementException:           #handling no such element exception
    name.append('No details available')
time.sleep(2)


#scrapping designation
designation=[]
try:
    designation_list=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/span[1]")
    for i in designation_list:
        designation.append(i.text)
except NoSuchElementException:        #handling no such element exception
    designation.append('No details available')
time.sleep(2)


#scrapping company names
company=[]
try:
    companies=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[2]")
    for i in companies:
        company.append(i.text)
except NoSuchElementException:#handling no such element exception
    company.append('No details available')
time.sleep(2)

#scrapping location names
location=[]
soup=BeautifulSoup(driver.page_source,'html.parser')
l=soup.find_all('div',attrs={'vcard'})
for i in l:
    try:
        location.append(i.find('small').text)
    except AttributeError :
        location.append("No details available")
time.sleep(2)

#skills they hire for
skill=[]
try:
    skills=driver.find_elements_by_xpath("//div[@class='recInfo']/div[2]")
    for i in skills:
        skill.append(i.text)
except NoSuchElementException:        #handling no such element exception
    skill.append('No details available')
time.sleep(2)    
        
#creating dataframe
df=pd.DataFrame({'Name':name,
                'Designation':designation,
                'Company':company,
                "Location":location,
                'Skills I hire':skill})
df
# Out:
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_4892/2180236053.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_4892/2180236053.py:11: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   recruiters=driver.find_element_by_xpath("//a[@title='Search Recruiters']")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# C:\Users\INDERJ~1\AppData\Local\Temp/ipykernel_4892/2180236053.py in <module>
#       9
#      10 #clicking on recruiters link
# ---> 11 recruiters=driver.find_element_by_xpath("//a[@title='Search Recruiters']")
#      12 driver.get(recruiters.get_attribute('href'))
#      13 time.sleep(1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     519             stacklevel=2,
#     520         )
# --> 521         return self.find_element(by=By.XPATH, value=xpath)
#     522
#     523     def find_elements_by_xpath(self, xpath) -> List[WebElement]:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1246             value = '[name="%s"]' % value
#    1247
# -> 1248         return self.execute(Command.FIND_ELEMENT, {
#    1249             'using': by,
#    1250             'value': value})['value']
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//a[@title='Search Recruiters']"}
#   (Session info: chrome=100.0.4896.127)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00C49943+2595139]
# 	Ordinal0 [0x00BDC9F1+2148849]
# 	Ordinal0 [0x00AD4528+1066280]
# 	Ordinal0 [0x00B00FD4+1249236]
# 	Ordinal0 [0x00B011CB+1249739]
# 	Ordinal0 [0x00B2D812+1431570]
# 	Ordinal0 [0x00B1BA34+1358388]
# 	Ordinal0 [0x00B2BAF2+1424114]
# 	Ordinal0 [0x00B1B806+1357830]
# 	Ordinal0 [0x00AF6086+1204358]
# 	Ordinal0 [0x00AF6F96+1208214]
# 	GetHandleVerifier [0x00DEB232+1658114]
# 	GetHandleVerifier [0x00EA312C+2411516]
# 	GetHandleVerifier [0x00CDF261+560433]
# 	GetHandleVerifier [0x00CDE366+556598]
# 	Ordinal0 [0x00BE286B+2173035]
# 	Ordinal0 [0x00BE75F8+2192888]
# 	Ordinal0 [0x00BE76E5+2193125]
# 	Ordinal0 [0x00BF11FC+2232828]
# 	BaseThreadInitThunk [0x75E4919F+14]
# 	RtlInitializeExceptionChain [0x7776AD1F+143]
# 	RtlInitializeExceptionChain [0x7776ACEA+90]
